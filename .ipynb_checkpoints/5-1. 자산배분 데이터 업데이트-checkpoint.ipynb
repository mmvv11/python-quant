# %%
import FinanceDataReader as fdr
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import timedelta
from time import sleep

def getCloseData(ticker, start, end=None):
    """
    종가 데이터
    ticker: 종목 번호
    start: 시작일
    end: 마지막 날짜
    return: 종목의 종가 데이터
    """
    return fdr.DataReader(ticker, start, end)['Close']

# %% [markdown]
# **자산배분 데이터 최신화**

# %%
# 기존 데이터 로드
data = pd.read_csv("./정적자산배분데이터.csv", index_col=0, parse_dates=True)
data
# Out:
#                   VTI     VBR        TLT        IEF        IEI       SHY  \
# 2010-01-04   46.08189   55.52   66.13332   71.24535   94.21502  75.39010
# 2010-01-05   46.25879   55.46   66.56042   71.55817   94.51414  75.48085
# 2010-01-06   46.32312   55.55   65.66942   71.26941   94.38595  75.48993
# 2010-01-07   46.51610   56.04   65.77987   71.26941   94.35176  75.47178
# 2010-01-08   46.66887   56.24   65.75042   71.35764   94.48850  75.54438
# ...               ...     ...        ...        ...        ...       ...
# 2022-07-27  200.86000  160.25  116.82000  104.10000  120.49000  82.88000
# 2022-07-28  203.48000  162.72  117.75000  105.13000  121.23000  83.06000
# 2022-07-29  206.25000  164.54  117.43000  105.17000  121.26000  83.05000
# 2022-08-01  205.77000  164.45  120.04000  105.60000  121.30000  82.96000
# 2022-08-02  204.66000  162.60  117.50000  104.14000  120.17000  82.67000
#
#               GSG     GLD
# 2010-01-04  32.70  109.80
# 2010-01-05  33.03  109.70
# 2010-01-06  33.27  111.51
# 2010-01-07  33.11  110.82
# 2010-01-08  33.18  111.37
# ...           ...     ...
# 2022-07-27  22.86  161.67
# 2022-07-28  22.79  163.64
# 2022-07-29  22.93  164.10
# 2022-08-01  22.25  165.03
# 2022-08-02  22.05  164.05
#
# [3167 rows x 8 columns]

# %%
# 티커 조회
tickers= data.columns
tickers
# Out:
# Index(['VTI', 'VBR', 'TLT', 'IEF', 'IEI', 'SHY', 'GSG', 'GLD'], dtype='object')

# %%
# 추가할 데이터의 시작점
start = data.index[-1]+timedelta(days=1)
start
# Out:
# Timestamp('2022-08-03 00:00:00')

# %%
# 빈 데이터 프레임 생성
newDf = pd.DataFrame()

# %%
# 최신 데이터 조회, 데이터프레임에 추가
for ticker in tickers:
    newData = getCloseData(ticker, start)
    newDf = pd.concat([newDf, newData], axis=1)
    sleep(5) # 요청 수 제한 방지를 위한 시간 텀
newDf
# Out:
#                       Close   Close   Close   Close   Close  Close  Close  \
# 2022-08-03 00:00:00  207.95  163.72  119.35  104.57  120.39   82.7  21.85
#
#                       Close
# 2022-08-03 00:00:00  164.45

# %%
# 컬럼과 인덱스 설정
newDf.columns = tickers
newDf.index = pd.to_datetime(newDf.index)
newDf
# Out:
#                VTI     VBR     TLT     IEF     IEI   SHY    GSG     GLD
# 2022-08-03  207.95  163.72  119.35  104.57  120.39  82.7  21.85  164.45

# %%
# 기존 데이터와 합치기
updatedData = pd.concat([data, newDf])
updatedData
# Out:
#                   VTI     VBR        TLT        IEF        IEI       SHY  \
# 2010-01-04   46.08189   55.52   66.13332   71.24535   94.21502  75.39010
# 2010-01-05   46.25879   55.46   66.56042   71.55817   94.51414  75.48085
# 2010-01-06   46.32312   55.55   65.66942   71.26941   94.38595  75.48993
# 2010-01-07   46.51610   56.04   65.77987   71.26941   94.35176  75.47178
# 2010-01-08   46.66887   56.24   65.75042   71.35764   94.48850  75.54438
# ...               ...     ...        ...        ...        ...       ...
# 2022-07-28  203.48000  162.72  117.75000  105.13000  121.23000  83.06000
# 2022-07-29  206.25000  164.54  117.43000  105.17000  121.26000  83.05000
# 2022-08-01  205.77000  164.45  120.04000  105.60000  121.30000  82.96000
# 2022-08-02  204.66000  162.60  117.50000  104.14000  120.17000  82.67000
# 2022-08-03  207.95000  163.72  119.35000  104.57000  120.39000  82.70000
#
#               GSG     GLD
# 2010-01-04  32.70  109.80
# 2010-01-05  33.03  109.70
# 2010-01-06  33.27  111.51
# 2010-01-07  33.11  110.82
# 2010-01-08  33.18  111.37
# ...           ...     ...
# 2022-07-28  22.79  163.64
# 2022-07-29  22.93  164.10
# 2022-08-01  22.25  165.03
# 2022-08-02  22.05  164.05
# 2022-08-03  21.85  164.45
#
# [3168 rows x 8 columns]

# %%
# 파일 업데이트
updatedData.to_csv("./동적자산배분데이터.csv")

# %% [markdown]
# **함수화**

# %%
def updateDynamicDataSet():
    """
    자산배분데이터 최신화
    from datetime import timedelta
    from time import sleep
    """
    data = pd.read_csv("./동적자산배분데이터.csv", index_col=0, parse_dates=True)
    tickers = data.columns

    start = data.index[-1]+timedelta(days=1)

    newDf = pd.DataFrame()

    for ticker in tickers:
        newData = getCloseData(ticker, start)
        newDf = pd.concat([newDf, newData], axis=1)
        sleep(5)

    newDf.columns = tickers
    newDf.index = pd.to_datetime(newDf.index)
    updatedData = pd.concat([data, newDf])
    updatedData.to_csv("./동적자산배분데이터.csv")
    return updatedData

# %%
def updateStaticDataSet():
    """
    자산배분데이터 최신화
    from datetime import timedelta
    from time import sleep
    """
    data = pd.read_csv("./정적자산배분데이터.csv", index_col=0, parse_dates=True)
    tickers = data.columns

    start = data.index[-1]+timedelta(days=1)

    newDf = pd.DataFrame()

    for ticker in tickers:
        newData = getCloseData(ticker, start)
        newDf = pd.concat([newDf, newData], axis=1)
        sleep(5)

    newDf.columns = tickers
    newDf.index = pd.to_datetime(newDf.index)
    updatedData = pd.concat([data, newDf])
    updatedData.to_csv("./정적자산배분데이터.csv")
    return updatedData

# %%
updateDynamicDataSet()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 updateDynamicDataSet()
# ----> 2 updateStaticDataSet()
#
# Input In [3], in updateStaticDataSet()
#      12 newDf = pd.DataFrame()
#      14 for ticker in tickers:
# ---> 15     newData = getCloseData(ticker, start)
#      16     newDf = pd.concat([newDf, newData], axis=1)
#      17     sleep(3)
#
# Input In [1], in getCloseData(ticker, start, end)
#       8 def getCloseData(ticker, start, end=None):
#       9     """
#      10     종가 데이터
#      11     ticker: 종목 번호
#    (...)
#      14     return: 종목의 종가 데이터
#      15     """
# ---> 16     return fdr.DataReader(ticker, start, end)['Close']
#
# File C:\anaconda\lib\site-packages\FinanceDataReader\data.py:44, in DataReader(symbol, start, end, exchange, data_source)
#      42 end = min([pd.to_datetime(end), datetime.today()])
#      43 while len(df) and df.index[-1] < end: # issues/30
# ---> 44     more = reader(symbol, df.index[-1] + timedelta(1), end, exchange, data_source).read()
#      45     if len(more) == 0:
#      46         break
#
# File C:\anaconda\lib\site-packages\FinanceDataReader\investing\data.py:83, in InvestingDailyReader.read(self)
#      77 headers = {
#      78     'User-Agent':'Mozilla/5.0 (Macintosh) AppleWebKit/537.36 Chrome/98.0.4758.109',
#      79     'X-Requested-With':'XMLHttpRequest',
#      80 }
#      82 r = requests.post(url, data, headers=headers)
# ---> 83 dfs = pd.read_html(StringIO(r.text))
#      84 df = dfs[0]
#      85 if (len(df)==0) or ("No results found" == df.iloc[0]['Date']):
#
# File C:\anaconda\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\anaconda\lib\site-packages\pandas\io\html.py:1098, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1094 validate_header_arg(header)
#    1096 io = stringify_path(io)
# -> 1098 return _parse(
#    1099     flavor=flavor,
#    1100     io=io,
#    1101     match=match,
#    1102     header=header,
#    1103     index_col=index_col,
#    1104     skiprows=skiprows,
#    1105     parse_dates=parse_dates,
#    1106     thousands=thousands,
#    1107     attrs=attrs,
#    1108     encoding=encoding,
#    1109     decimal=decimal,
#    1110     converters=converters,
#    1111     na_values=na_values,
#    1112     keep_default_na=keep_default_na,
#    1113     displayed_only=displayed_only,
#    1114 )
#
# File C:\anaconda\lib\site-packages\pandas\io\html.py:926, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     924 else:
#     925     assert retained is not None  # for mypy
# --> 926     raise retained
#     928 ret = []
#     929 for table in tables:
#
# File C:\anaconda\lib\site-packages\pandas\io\html.py:906, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     903 p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     905 try:
# --> 906     tables = p.parse_tables()
#     907 except ValueError as caught:
#     908     # if `io` is an io-like object, check if it's seekable
#     909     # and try to rewind it before trying the next parser
#     910     if hasattr(io, "seekable") and io.seekable():
#
# File C:\anaconda\lib\site-packages\pandas\io\html.py:222, in _HtmlFrameParser.parse_tables(self)
#     214 def parse_tables(self):
#     215     """
#     216     Parse and return all tables from the DOM.
#     217
#    (...)
#     220     list of parsed (header, body, footer) tuples from tables.
#     221     """
# --> 222     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File C:\anaconda\lib\site-packages\pandas\io\html.py:552, in _BeautifulSoupHtml5LibFrameParser._parse_tables(self, doc, match, attrs)
#     549 tables = doc.find_all(element_name, attrs=attrs)
#     551 if not tables:
# --> 552     raise ValueError("No tables found")
#     554 result = []
#     555 unique_tables = set()
#
# ValueError: No tables found

# %%
updateStaticDataSet()
# Out:
#                   VTI     VBR        TLT        IEF        IEI       SHY  \
# 2010-01-04   46.08189   55.52   66.13332   71.24535   94.21502  75.39010
# 2010-01-05   46.25879   55.46   66.56042   71.55817   94.51414  75.48085
# 2010-01-06   46.32312   55.55   65.66942   71.26941   94.38595  75.48993
# 2010-01-07   46.51610   56.04   65.77987   71.26941   94.35176  75.47178
# 2010-01-08   46.66887   56.24   65.75042   71.35764   94.48850  75.54438
# ...               ...     ...        ...        ...        ...       ...
# 2022-07-27  200.86000  160.25  116.82000  104.10000  120.49000  82.88000
# 2022-07-28  203.48000  162.72  117.75000  105.13000  121.23000  83.06000
# 2022-07-29  206.25000  164.54  117.43000  105.17000  121.26000  83.05000
# 2022-08-01  205.77000  164.45  120.04000  105.60000  121.30000  82.96000
# 2022-08-02  204.66000  162.60  117.50000  104.14000  120.17000  82.67000
#
#               GSG     GLD
# 2010-01-04  32.70  109.80
# 2010-01-05  33.03  109.70
# 2010-01-06  33.27  111.51
# 2010-01-07  33.11  110.82
# 2010-01-08  33.18  111.37
# ...           ...     ...
# 2022-07-27  22.86  161.67
# 2022-07-28  22.79  163.64
# 2022-07-29  22.93  164.10
# 2022-08-01  22.25  165.03
# 2022-08-02  22.05  164.05
#
# [3167 rows x 8 columns]
