# %% [markdown]
# FinanceDataReader 설치와 간단한 사용법
#
# https://financedata.github.io/posts/finance-data-reader-users-guide.html

# %% [markdown]
# 금융 데이터 수집 라이브러리, 이 외에도 다른 라이브러리도 있지만, 사용하기 간편하고 백테스트하는데 무리없이 사용가능 함
#
# 1. 이것 말고도 다양한 라이브러리가 존재한다.
# 2. 크롤링으로도 가져올 수 있고 여러 방법이 있지만,
# 3. 수업을 진행하면서는 finace data reader 라이브러리를 활용해볼 것이다.

# %%
pip install -U finance-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import FinanceDataReader as fdr

# %%
# test
fdr.DataReader("005930", "2020") # 삼성전자 종목번호를 넣고 돌리기
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921
# ...           ...    ...    ...    ...       ...       ...
# 2022-06-16  61300  61800  60500  60900  23394895  0.003295
# 2022-06-17  59400  59900  59400  59800  29053450 -0.018062
# 2022-06-20  59800  59900  58100  58700  34111306 -0.018395
# 2022-06-21  58700  59200  58200  58500  25148109 -0.003407
# 2022-06-22  59000  59100  57900  58200  14016019 -0.005128
#
# [611 rows x 6 columns]

# %%
# test
fdr.DataReader("SPY", "2020") # 삼성전자 종목번호를 넣고 돌리기
# Out:
#              Close    Open    High     Low       Volume  Change
# Date
# 2020-01-02  324.87  323.54  324.89  322.53   59250000.0  0.0094
# 2020-01-03  322.41  321.16  323.64  321.10   77780000.0 -0.0076
# 2020-01-06  323.64  320.49  323.73  320.36   55760000.0  0.0038
# 2020-01-07  322.73  323.02  323.54  322.24   42850000.0 -0.0028
# 2020-01-08  324.45  322.94  325.78  322.67   68430000.0  0.0053
# ...            ...     ...     ...     ...          ...     ...
# 2022-06-14  373.87  376.85  377.94  370.59  102300000.0 -0.0030
# 2022-06-15  379.20  377.36  383.90  372.12  124010000.0  0.0143
# 2022-06-16  366.65  370.51  370.94  364.08  133250000.0 -0.0331
# 2022-06-17  365.86  365.51  369.38  362.17  111110000.0 -0.0022
# 2022-06-21  375.07  371.89  376.52  371.81   75500000.0  0.0252
#
# [622 rows x 6 columns]
